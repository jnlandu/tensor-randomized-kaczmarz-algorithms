# %% [markdown]
# ### A test notebook for the tensor kaczmarz project

# %%
# !pip install -q git+https://github.com/jnlandu/tensor-randomized-kaczmarz-algorithms

# %%
import trk_algorithms as trk
trk.__version__
# Out:
# '0.1.0'

# %%
import torch

# %%
from trk_algorithms.utils import make_tensor_problem

# %%
# Create test problem
m, n, p, q = 150, 100, 10, 10
noise = 0.01
dtype = torch.float32
eta = 0.5
max_iter = 5000

A, X_ls, B = make_tensor_problem(m=m, n=n, p=p, q=q, noise=noise, seed=1, dtype=dtype)
print(f"Tensor dimensions: A: {A.shape}, B: {B.shape}, X: {X_ls.shape}")
# Out:
# /Users/jeremie/Documents/Papers/tensor-kaczmarz/.venv/lib/python3.13/site-packages/tensor_toolbox/tensorLinalg.py:251: UserWarning: The operator 'aten::linalg_svd' is not currently supported on the MPS backend and will fall back to run on the CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/mps/MPSFallback.mm:15.)
#   Xf[:, :, s] = torch.linalg.pinv(As, rcond=rcond) @ Bs
# Tensor dimensions: A: torch.Size([150, 100, 10]), B: torch.Size([150, 10, 10]), X: torch.Size([100, 10, 10])
